# %% [markdown]
# # Análisis
#
# Este documento explora correlaciones entre los componentes de pilares de iEcosystems, tales como
#
# * I-Funding
# * E-Funding
# * Comparative Advantage
# * Impact
#
# Así como sus relaciones con métricas globales de los ecosistemas, como aquellas métricas que describen la
#
# * comunicación
# * robustez
# * estabilidad
# * propensión al colapso

# %% [markdown]
# ### Parte 1: Importe de paquetes y definición de funciones
#
# En esta sección importamos los paquetes que utilizaremos, y también definimos las funciones que van a sustentar nuestro análisis de correlaciones.

# %%
import numpy as np 
import pandas as pd 
import matplotlib as plt

import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
def significant_corr(df1,df2,a,b):
    '''
    This function computed the pearson correlation between two data sets a, b, 
    and determines whether this correlation is significant or not. 
    
    Inputs:
    - df1  : a DataFrame
    - df2  : a DataFrame
    - a    : a data vector
    - b    : a data vector
    
    Output : a tuple (B,N) where B is a boolean that answers the question:
    ~do a and b present significant correlation? i.e. p-value<0.1,
    and N=0 is B=False, or N=p-val(a,b) if B=True
    '''
    if df2.empty:
        df2=df1
    r = stats.pearsonr(df1[a], df2[b])
    if r[1] < 0.1:
        return (True,r[0])
    else:
        return (False,0)
    
    
    

def print_significant_corr(df1,df2,a,b):
    '''
    This function computes the Pearson correlation between two data sets a, b, 
    and prints whether this correlation is significant or not, and the 
    corresponding Pearson correlation and p-value. 
    
    Inputs:
    - df1  : a DataFrame
    - df2  : a DataFrame
    - a    : a data vector
    - b    : a data vector
    
    Output : None, but executes print statements showing the findings about aand b.
    '''
    if df2.empty:
        df2=df1
    r = stats.pearsonr(df1[a], df2[b])
    if r[1] < 0.1:
        print(f'Correlation between:  ' + a + '   and   ' + b)
        print('**********************************************')
        print(f'Pearson Correlation: {r[0]}, p-value: {r[1]}')
        print('*Statistically significant*')
        print('***********************************************')

# %% [markdown]
# ### Parte 2: Carga de Datos
#
# En la siguiente viñeta conseguimos los siguientes DataFrames, con base en los cuales vamos a realizar nustro análisis:
# * `df_means`, que contiene las métricas de iEcosystems de 106 países promediadas por pilar
# * `grf_df`, que contiene las métricas de grafo de los ecosistemas estudiados, así como las métricas de colaboratividad
# * `ranking_df`, que contiene la evaluación de cada ciudad respecto a las métricas de colaboratividad propuestas, así como su ranking de acuerdo a dicha métrica
# *  `full_eco_df`, que contiene las métricas de iEcosystems de 106 países, así como cada pilar desglosado

# %%
#Métricas iEcosystems por pillar
df_means = pd.read_csv('Referenced_CSVs/PromediosPilares_nuevo_ieco.csv')


#Valores de métricas y de colaboratividad por ciudad
grf_df = pd.read_csv('Referenced_CSVs/Tidy_DataFrame.csv')

#Rankings de cada ciudad de acuerdo a métricas de colaboratividad
ranking_df = pd.read_csv('Referenced_CSVs/Ranking_cities.csv')


#Todos los pilares de iEco desglosados
full_ieco_df = pd.read_csv('Referenced_CSVs/full_iEco.csv')

# %% [markdown]
# ### Parte 3: Formación de DataFrames enfocados en las capitales
#
# De los DataFrames obtenidos, nos enfocamos en aquellos correspondientes a las ciudades capitales estudiadas.

# %%
'''DataFrame de métricas de grafos'''

capitalnames = ['CDMX', 'CABA', 'Santiago', 'Sao Paulo', 'Madrid', 'Montevideo']
grf_df = grf_df.loc[grf_df['Ciudad'].isin(capitalnames)]

grf_df = grf_df.drop('Ciudad', axis=1)
grf_df.set_index('País', inplace=True)  #Nombramos País como índice

grf_df
# Out:
#            avg strength    weight    Degree  Weighted Degree  Excentricidad  \
# País
# Argentina      3.244633  1.481579  4.385965        14.017544       4.798246
# México         3.477388  1.388629  3.658863        12.963211       5.622074
# Chile          3.417211  1.462564  3.948718        13.764103       5.041026
# Uruguay        3.227742  2.749495  7.747475        25.939394       4.479798
# España         3.518387  1.362343  3.790795        12.861925       6.079498
# Brasil         3.430669  1.253704  3.370370        11.694444       6.726852
#
#            Clustering  Diámetro  Radio  Camino más corto promedio  \
# País
# Argentina    0.300215         6      3                   3.355669
# México       0.178788         7      4                   3.820318
# Chile        0.311157         6      3                   3.227544
# Uruguay      0.367266         6      3                   3.081116
# España       0.266684         8      5                   3.783517
# Brasil       0.295414         8      4                   4.324031
#
#            Transitividad  ...   Colab 6   Colab 7   Colab 8   Colab 9  \
# País                      ...
# Argentina       0.107392  ...  0.277219  0.322560  0.364099  0.343969
# México          0.050000  ...  0.197206  0.286659  0.308942  0.304868
# Chile           0.100744  ...  0.271107  0.316215  0.357342  0.340056
# Uruguay         0.224523  ...  0.373899  0.349355  0.431910  0.385176
# España          0.081917  ...  0.228465  0.287951  0.316629  0.309405
# Brasil          0.078571  ...  0.211309  0.255960  0.269424  0.284577
#
#            Colab 10  Colab 11  Colab 12  Colab 13  Colab 14  Colab 10 rescaled
# País
# Argentina  0.492850  0.314246  0.312265  0.388024  0.427003           5.928502
# México     0.397667  0.267167  0.266965  0.342306  0.320264           4.976668
# Chile      0.480988  0.311826  0.293944  0.369558  0.407755           5.809878
# Uruguay    0.588490  0.360937  0.360646  0.436381  0.502732           6.884901
# España     0.426240  0.286349  0.278308  0.353561  0.403647           5.262402
# Brasil     0.384944  0.250892  0.251874  0.326146  0.295488           4.849443
#
# [6 rows x 34 columns]

# %%
'''DataFrame de promedios de pilares'''

df_means.set_index('Country', inplace=True)
countries={'Mexico':'México',
          'Uruguay':'Uruguay',
          'Spain':'España',
          'Brazil':'Brasil',
          'Argentina':'Argentina',
          'Chile':'Chile'}
df_means = df_means.loc[list(countries.keys()), :]
df_means.rename(index=countries, inplace=True)
df_means
# Out:
#            1 Foundational Institutions  2.01 I-Human Capital  2.02 I-Funding  \
# Country
# México                          3.5224              2.363914        1.238062
# Uruguay                         3.7808              2.234182        1.464989
# España                          3.9268              2.822386        1.899159
# Brasil                          3.1780              1.826706        1.662244
# Argentina                       3.1684              2.051076        1.682002
# Chile                           3.9124              2.413203        1.184934
#
#            2.03 I-Infrastructure  2.04 I-Demand  2.05 I-Culture & Incentives  \
# Country
# México                  2.782979       3.102667                       2.5160
# Uruguay                 2.833698       2.578222                       1.2428
# España                  3.191020       3.077333                       3.8300
# Brasil                  2.707140       2.879111                       2.7542
# Argentina               2.740698       2.729778                       1.7930
# Chile                   3.100109       2.965778                       1.9536
#
#            3.01 E-Human Capital  3.02 E-Funding  3.03 E-Infrastructure  \
# Country
# México                 3.117368        2.299475               3.701600
# Uruguay                3.046434        2.006702               3.926000
# España                 3.189806        2.423851               4.264933
# Brasil                 2.975761        1.991287               3.694933
# Argentina              3.076940        1.725475               3.679067
# Chile                  4.154179        2.207990               3.935067
#
#            3.04 E-Demand  3.05 E-Culture & Incentives  \
# Country
# México            3.4260                     2.953330
# Uruguay           2.7408                     3.051111
# España            3.3650                     2.614589
# Brasil            3.4638                     3.376030
# Argentina         3.1718                     2.891282
# Chile             3.2030                     3.469417
#
#            4 Comparative Advantage  5 Social Impact  6 Economic Impact  \
# Country
# México                    2.928133         3.916166           2.665218
# Uruguay                   2.482667         4.489483           2.605598
# España                    2.839333         4.111115           2.675696
# Brasil                    2.741067         3.996738           2.389177
# Argentina                 2.583067         3.984246           2.405071
# Chile                     3.111200         4.424643           2.676299
#
#            GNI per capita  SEDA Score
# Country
# México           1.440818       2.968
# Uruguay          1.772041       3.560
# España           2.461763       3.900
# Brasil           1.426206       2.972
# Argentina        1.527034       3.232
# Chile            1.712616       3.504

# %%
'''DataFrame: por capital, desglose de cada pilar de iEcosystems.'''

full_ieco_df = full_ieco_df.rename(columns={'Unnamed: 0': 'País'})
full_ieco_df.set_index('País', inplace=True)
full_ieco_df
# Out:
#            1.01 Ease of doing business (WB)  1.02 Starting a business (WB)  \
# País
# México                                 3.90                           4.44
# Argentina                              3.36                           4.22
# Chile                                  3.90                           4.66
# Brasil                                 3.36                           4.25
# España                                 4.12                           4.48
# Uruguay                                3.46                           4.58
#
#            1.03 Paying taxes (WB)  1.04 Resolving Insolvency (WB)  \
# País
# México                       3.63                            3.81
# Argentina                    2.97                            2.60
# Chile                        4.01                            3.40
# Brasil                       2.38                            3.02
# España                       4.39                            4.17
# Uruguay                      3.81                            3.14
#
#            1.05 Enforcing contracts (WB)  1.06 Property Rights (IEF)  \
# País
# México                              3.68                        3.33
# Argentina                           3.30                        3.02
# Chile                               3.59                        3.80
# Brasil                              3.56                        3.29
# España                              3.84                        4.00
# Uruguay                             3.25                        3.88
#
#            1.07 Government Integrity (IEF)  1.08 Labor Freedom (IEF)  \
# País
# México                                2.47                      3.34
# Argentina                             2.99                      2.86
# Chile                                 3.94                      3.59
# Brasil                                2.82                      2.98
# España                                3.20                      3.31
# Uruguay                               3.94                      3.84
#
#            1.09 Trade freedom (IEF)  1.10 Corruption Perceptions Index (TI)  \
# País
# México                         4.50                                    2.12
# Argentina                      3.77                                    2.60
# Chile                          4.56                                    3.68
# Brasil                         3.71                                    2.40
# España                         4.46                                    3.32
# Uruguay                        4.10                                    3.80
#
#            ...  5.02 Social Progress Index  5.03 Inclusive Development Index  \
# País       ...
# México     ...                        3.82                              3.08
# Argentina  ...                        4.07                              3.09
# Chile      ...                        4.20                              3.29
# Brasil     ...                        3.91                              2.95
# España     ...                        4.50                              3.27
# Uruguay    ...                        4.11                              3.31
#
#            5.04 Population below international poverty line (SDG 1 - No poverty)  \
# País
# México                                                  4.80
# Argentina                                               4.97
# Chile                                                   4.94
# Brasil                                                  4.61
# España                                                  4.92
# Uruguay                                                 4.99
#
#            5.05 Prevalence of undernourishment (SDG 2 - Zero Hunger)  \
# País
# México                                                  4.88
# Argentina                                               4.88
# Chile                                                   4.93
# Brasil                                                  5.00
# España                                                  5.00
# Uruguay                                                 5.00
#
#            5.06 Annual growth rate of real GDP per capita (SDG 8 - Decent Jobs and Economic Growth)  \
# País
# México                                                  3.34
# Argentina                                               3.58
# Chile                                                   3.32
# Brasil                                                  3.22
# España                                                  3.82
# Uruguay                                                 3.67
#
#            5.07 Unemployment rate of population 15 years of age and older (SDG 8 - Decent Jobs and Economic Growth)  \
# País
# México                                                  4.72
# Argentina                                               3.94
# Chile                                                   4.16
# Brasil                                                  3.26
# España                                                  2.57
# Uruguay                                                 4.02
#
#            5.08 Carbon dioxide emissions per unit of GDP (SDG 9 - Industry, Innovation and Infrastructure)  \
# País
# México                                                  4.33
# Argentina                                               4.20
# Chile                                                   4.29
# Brasil                                                  4.60
# España                                                  4.56
# Uruguay                                                 4.87
#
#            5.09 Proportion of urban population living in slums (SDG 11 - Sustainable Cities and Communities)  \
# País
# México                                              4.520000
# Argentina                                           4.580000
# Chile                                               4.840000
# Brasil                                              4.510000
# España                                              4.900000
# Uruguay                                             4.643333
#
#            5.10 Annual population-weighted average mean concentration of fine suspended particles of less than 2.5 microns in diameter (SDG 11 - Sustainable Cities and Communities)  \
# País
# México                                                  4.32
# Argentina                                               4.71
# Chile                                                   4.28
# Brasil                                                  4.73
# España                                                  4.82
# Uruguay                                                 4.87
#
#            5.11 Domestic material consumption per capita (SDG 12 - Responsible Consumption and Production)
# País
# México                                                  1.71
# Argentina                                               2.03
# Chile                                                   5.00
# Brasil                                                  2.18
# España                                                  1.68
# Uruguay                                                 4.32
#
# [6 rows x 61 columns]

# %% [markdown]
# Concatenaciones de los DataFrames anteriores:

# %%
'''DataFrame: por país, concatenación de promedios de ieco y métricas de grafo'''

ieco_grf_df = pd.concat([df_means, grf_df], axis=1)
ieco_grf_df
# Out:
#            1 Foundational Institutions  2.01 I-Human Capital  2.02 I-Funding  \
# México                          3.5224              2.363914        1.238062
# Uruguay                         3.7808              2.234182        1.464989
# España                          3.9268              2.822386        1.899159
# Brasil                          3.1780              1.826706        1.662244
# Argentina                       3.1684              2.051076        1.682002
# Chile                           3.9124              2.413203        1.184934
#
#            2.03 I-Infrastructure  2.04 I-Demand  2.05 I-Culture & Incentives  \
# México                  2.782979       3.102667                       2.5160
# Uruguay                 2.833698       2.578222                       1.2428
# España                  3.191020       3.077333                       3.8300
# Brasil                  2.707140       2.879111                       2.7542
# Argentina               2.740698       2.729778                       1.7930
# Chile                   3.100109       2.965778                       1.9536
#
#            3.01 E-Human Capital  3.02 E-Funding  3.03 E-Infrastructure  \
# México                 3.117368        2.299475               3.701600
# Uruguay                3.046434        2.006702               3.926000
# España                 3.189806        2.423851               4.264933
# Brasil                 2.975761        1.991287               3.694933
# Argentina              3.076940        1.725475               3.679067
# Chile                  4.154179        2.207990               3.935067
#
#            3.04 E-Demand  ...   Colab 6   Colab 7   Colab 8   Colab 9  \
# México            3.4260  ...  0.197206  0.286659  0.308942  0.304868
# Brasil     0.251874  0.326146  0.295488           4.849443
# España     0.278308  0.353561  0.403647           5.262402
# Uruguay    0.360646  0.436381  0.502732           6.884901
#
# [6 rows x 95 columns]

# %% [markdown]
# Se promedian los pilares de Impacto Social e Impacto Económico.

# %%
ieco_grf_df['Impact'] = ieco_grf_df['5 Social Impact']+ieco_grf_df['6 Economic Impact']
ieco_global_corr_df =   ieco_grf_df.corr()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#ieco_global_corr_df

# %% [markdown]
# ### Parte 4: Visualización de correlaciones
#
# En esta sección se realiza una visualización de las correlaciones entre todas las métricas de iEcosystems y las métricas de grafo.

# %%
sns.set(style="white")

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(ieco_global_corr_df, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(32, 24))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(ieco_global_corr_df, mask=mask, cmap=cmap, annot=True, vmin=-1, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
ieco_grf_df
# Out:
#            1 Foundational Institutions  2.01 I-Human Capital  2.02 I-Funding  \
# México                          3.5224              2.363914        1.238062
# Uruguay                         3.7808              2.234182        1.464989
# España                          3.9268              2.822386        1.899159
# Brasil                          3.1780              1.826706        1.662244
# Argentina                       3.1684              2.051076        1.682002
# Chile                           3.9124              2.413203        1.184934
#
#            2.03 I-Infrastructure  2.04 I-Demand  2.05 I-Culture & Incentives  \
# México                  2.782979       3.102667                       2.5160
# Uruguay                 2.833698       2.578222                       1.2428
# España                  3.191020       3.077333                       3.8300
# Brasil                  2.707140       2.879111                       2.7542
# Argentina               2.740698       2.729778                       1.7930
# Chile                   3.100109       2.965778                       1.9536
#
#            3.01 E-Human Capital  3.02 E-Funding  3.03 E-Infrastructure  \
# México                 3.117368        2.299475               3.701600
# Uruguay                3.046434        2.006702               3.926000
# España                 3.189806        2.423851               4.264933
# Brasil                 2.975761        1.991287               3.694933
# Argentina              3.076940        1.725475               3.679067
# Chile                  4.154179        2.207990               3.935067
#
#            3.04 E-Demand  ...   Colab 7   Colab 8   Colab 9  Colab 10  \
# México            3.4260  ...  0.286659  0.308942  0.304868  0.397667
# Uruguay           2.7408  ...  0.349355  0.431910  0.385176  0.588490
# España            3.3650  ...  0.287951  0.316629  0.309405  0.426240
# Brasil            3.4638  ...  0.255960  0.269424  0.284577  0.384944
# Argentina         3.1718  ...  0.322560  0.364099  0.343969  0.492850
# Chile             3.2030  ...  0.316215  0.357342  0.340056  0.480988
#
#            Colab 11  Colab 12  Colab 13  Colab 14  Colab 10 rescaled    Impact
# México     0.267167  0.266965  0.342306  0.320264           4.976668  6.581383
# Uruguay    0.360937  0.360646  0.436381  0.502732           6.884901  7.095082
# España     0.286349  0.278308  0.353561  0.403647           5.262402  6.786811
# Brasil     0.250892  0.251874  0.326146  0.295488           4.849443  6.385915
# Argentina  0.314246  0.312265  0.388024  0.427003           5.928502  6.389317
# Chile      0.311826  0.293944  0.369558  0.407755           5.809878  7.100943
#
# [6 rows x 51 columns]

# %% [markdown]
# La correlación entre el pilar de Impacto y Colaboraciones Provenientes del Archivo Excel Original es la siguiente:

# %%
colabs_excel=np.array([3.64,5.81,5.60,3.28,4.27,8.47])
r = stats.pearsonr(ieco_grf_df['Impact'], colabs_excel)
r
# Out:
# (0.8581901791330292, 0.028739138399174472)

# %%
def check_formula(i):
    print('Checking Formula '+str(i))
    print('---')
    print('Correlation with 5 Impact')
    print(stats.pearsonr(ieco_grf_df['Impact'], ieco_grf_df['Colab '+str(i)]))
    print('---')
    
check_formula(10)
# Out:
# Checking Formula 10
# ---
# Correlation with 5 Impact
# (0.6224336197598077, 0.18692231065013218)
# ---

# %%
for i in range(11):
    #check_formula(i)
    1

# %% [markdown]
# #### Correlaciones Significativas, Positivas y Negativas
#
# * Primero, entre Pilares de iEcosystems y metricas globales de grafo
# * Luego, entre componentes de I-Demanda y metricas globales de grafo
# * Luego, entre componentes de E-Demanda y metricas globales de grafo

# %%
#------------------
# iEco - Métricas
#------------------

list1=list(df_means.keys())     #Pilares de iEcosystems
list2=list(grf_df.keys())       #Nombres de metricas globales

positive_pairs=[]
negative_pairs=[]

for key1 in list1:             # m(iEco,graph) : correlacion significativa?
    for key2 in list2:
        sig,corr=significant_corr(ieco_grf_df,ieco_grf_df,key1,key2)
        if sig==True:
            if corr>0:
                positive_pairs.append((key1,key2))    # sig.corr > 0
            else:
                negative_pairs.append((key1,key2))    # sig.corr <=0

# %%
#Imprime correlaciones significativas y positivas (+)

for keys in positive_pairs:
    1
    #print('')
    #print_significant_corr(ieco_grf_df,ieco_grf_df,keys[0],keys[1])
    #print('')

# %%
#Imprime correlaciones significativas y negativas (-)

for keys in negative_pairs:
    1
    #print('')
    #print_significant_corr(ieco_grf_df,ieco_grf_df,keys[0],keys[1])
    #print('')

# %%
#----------------------
# I-Demand - Métricas
#----------------------

#I-Demand
list1=['2.04a Government procurement of advanced technology (GCI)',
       '2.04b University-industry research collaborations (GII)',
       '2.04c Trade, Competition & Market scale (GII)',
       '3.04a Buyer sophistication (GCI 4.0)',
       '3.04b Domestic Market Scale (GII)']    

#metricas globales
list2=list(grf_df.keys())

positive_pairs_2=[]
negative_pairs_2=[]

for key1 in list1:                     #por cada componente de IDemand, métrica global revisamos corr. significativa
    for key2 in list2:                 
        sig,corr = significant_corr(full_ieco_grf_df,full_ieco_grf_df,key1,key2)
        if sig == True:
            if corr > 0:
                positive_pairs_2.append((key1,key2))        #correlación significativa positiva
            else:
                negative_pairs_2.append((key1,key2))        #correlación significativa negativa

# %%
#Imprime correlaciones significativas y positivas (+)

for keys in positive_pairs_2:
    1
    #print('')
    #print_significant_corr(full_ieco_grf_df,full_ieco_grf_df,keys[0],keys[1])
    #print('')

# %%
#El texto impreso es una lista de correlaciones significativas y negativas que encontramos (-)

for keys in negative_pairs_2:
    1
    #print('')
    #print_significant_corr(full_ieco_grf_df,full_ieco_grf_df,keys[0],keys[1])
    #print('')

# %%
#--------------------
# Impacto - Métricas
#--------------------

list1=list(full_ieco_df.keys())[-9:]                #Pilar Impacto
list2=list(grf_df.keys())                           #Metricas globales

positive_pairs_3=[]
negative_pairs_3=[]

for key1 in list1:                                  #revisamos en cada pareja si hay corr. significativa + o -
    for key2 in list2:
        sig,corr=significant_corr(full_ieco_grf_df,full_ieco_grf_df,key1,key2)
        if sig==True:
            if corr>0:
                positive_pairs_3.append((key1,key2))
            else:
                negative_pairs_3.append((key1,key2))

# %%
#Imprime correlaciones significativas y positivas (+)

for keys in positive_pairs_3:
    1
    #print('')
    #print_significant_corr(full_ieco_grf_df,full_ieco_grf_df,keys[0],keys[1])
    #print('')

# %%
#Imprime correlaciones significativas y negativas (-)

for keys in positive_pairs_3:
    1
    #print('')
    #print_significant_corr(full_ieco_grf_df,full_ieco_grf_df,keys[0],keys[1])
    #print('')

# %% [markdown]
# ### Parte 5: Regresiones Lineales

# %%
from sklearn.linear_model import LinearRegression
from scipy import stats
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d



def lin_reg_p_val(reg,X,y):
    '''
    Esta función busca el p-value entre
    
    - X : np.array
    - y : vector de datos
    
    Es decir, mide la correlación entre un conjunto de puntos X 
    determinado por una pareja de variables y un cnjunto de valores y.
    
    Inputs : specified above
    Output : p-value(X,y)
    '''
    
    # predice el np.array X usando modelo lineal, y suma las distancias al cuadrado de esa predicción hacia y
    # luego divide entre  (X.shape[0] - X.shape[1])= (no.columnas, no.filas)
    sse = np.sum((reg.predict(X) - y) ** 2, axis=0) / float(X.shape[0] - X.shape[1])
    
    if isinstance(sse, float):  
        
        # si sse es un valor decimal, entonces forma se, una matriz (np.array) que al cuadrado
        # es igual a diag( sse * (X^T * X)^-1 ) 
        
        se = np.array([np.sqrt(np.diagonal(sse * np.linalg.inv(np.dot(X.T, X))))])  
        
    else: 
        # si sse no es un valor decimal sino un np.array, entonces se forma se, una lista tal que
        # por cada columna i, el valor se[i]^2 = diag( sse[i] * (X^T * X)^-1 ) 
        
        se = np.array([np.sqrt(np.diagonal(sse[i] * np.linalg.inv(np.dot(X.T, X)))) for i in range(sse.shape[0])])
    
    # p-value entre (X,Y)
    t = reg.coef_ / se
    p = 2 * (1 - stats.t.cdf(np.abs(t), y.shape[0] - X.shape[1]))
    return p




def plot_linear_model(reg,X,y,key1,key2,predict):
    '''
    This function plots the linear modeling of a vector of variables y in terms of 
    a set of points X, determined by 2 data vectors. 
    
    Inputs:
    - reg :     regression model 
    - X :       a set of points representing some data vectors.
    - y :       data which is to be predicted from the other data vectors
    - key1 :    sring for axis label -> predicting data
    - key2 :    sring for axis label -> predicting data
    - predict : string for axis label -> predicted data
    
    Outputs: 
    None, and a ~very nice~ 3D plot showing how good 
    data collection X might be in predicting linearly data vector y.
    '''
    
    ax = plt.axes(projection='3d')      #setup of 3D projection
    plt.tight_layout()
    
    a = np.linspace(1, 5, 30)           #a,b : grids with 30 equidistant values in (1,5)
    b = np.linspace(1, 5, 30)
    
    A,B = np.meshgrid(a,b)           
    C = A*reg.coef_[0] + B*reg.coef_[1] + reg.intercept_   # plane approximates y by X
    
    
    ax.scatter3D(X[:,0], X[:,1], y, cmap='Greens')         # Scatter X (green)
    ax.contour3D(A, B, C, 50, cmap='binary')               # 3D contour of the linear approx
    
    
    ax.set_title('Linear Model')                           # Title, coords, lims 
    ax.set_xlabel(key1, fontsize=9)                                    
    ax.set_ylabel(key2, fontsize=9)
    ax.set_zlabel(predict, fontsize=9)
    plt.xlim((1,5))
    plt.ylim((1,5))
    plt.show()                                             #pull down the curtains!

# %% [markdown]
# #### Modelo linear de 4 dimensiones
#
# Se obtiene mucha información a analizar, posiblemente no es útil.
# No se continuó este análisis con más dimensiones, ya que sucedería algo parecido
# ~ Cualesquiera $n+1$ puntos están sobre un hiperplano $n$-dimensional

# %%
ieco_key_list=list(df_means.keys())
ieco_key_list.remove('4 Comparative Advantage')
ieco_key_list.remove('5 Social Impact')                            #ieco pilars but 4,5


ieco_key_predictors=['4 Comparative Advantage','5 Social Impact']  #data to predict


grf_key_list=list(grf_df.keys())                            #graph global metrics 


for key1 in ieco_key_list:     
    for key2 in ieco_key_list:
        if key1 != key2:
            for key3 in ieco_key_list:
                if key3 !=key1 and key3 !=key2:         # for every (a,b,c) different ieco metrics
                    
                    for predict in ieco_key_predictors: 
                        #X=np.concatenate([ieco_df[key1].to_numpy(),ieco_df[key2].to_numpy(),ieco_df[key3].to_numpy()],axis=0)
                        X = np.concatenate([df_means[key1].to_numpy(),df_means[key2].to_numpy(),df_means[key3].to_numpy()],axis=0)
                        X = X.reshape(6,3)
                        y = df_means[predict].to_numpy()
                        reg = LinearRegression().fit(X,y)
                        p = lin_reg_p_val(reg,X,y)
                        if p[0][0]<.05 and p[0][1]<.05 and p[0][2]<.05 and reg.score(X,y)>.9:
                            print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -')
                            print('Predictor metrics: '+key1+', '+key2+', '+key3)
                            print('Predicted: '+predict)
                            print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -')
                            print('Regression Score: ' + str(reg.score(X,y)) + ', p-value: ' + str(p) )
                            print('Regression Coefficients: ' + str(reg.coef_) )
                            print('')
                            print('')
                            print('')
# Out:
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 1 Foundational Institutions, 2.02 I-Funding, 3.03 E-Infrastructure
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9626609973525, p-value: [[0.00520207 0.00300066 0.01164813]]
# Regression Coefficients: [ 1.48330159 -1.87623323  0.3851877 ]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 1 Foundational Institutions, 2.03 I-Infrastructure, 2.01 I-Human Capital
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9819033651386696, p-value: [[0.008526   0.00155504 0.01987356]]
# Regression Coefficients: [-1.09464452  1.36646891 -0.45114714]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 1 Foundational Institutions, 2.04 I-Demand, 6 Economic Impact
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9612568863234172, p-value: [[0.00568006 0.02220765 0.00370823]]
# Regression Coefficients: [-0.85091764 -0.58074131  1.02271316]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 1 Foundational Institutions, 3.02 E-Funding, 3.01 E-Human Capital
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9683051606504565, p-value: [[0.00123571 0.00081132 0.0017636 ]]
# Regression Coefficients: [ 1.43891205 -1.70879557  0.70642338]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 1 Foundational Institutions, 3.03 E-Infrastructure, 2.01 I-Human Capital
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9721095803158833, p-value: [[0.01424936 0.00243378 0.00717469]]
# Regression Coefficients: [-0.85105487  1.31341224 -0.61119556]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 1 Foundational Institutions, 3.03 E-Infrastructure, 2.04 I-Demand
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9274297280570508, p-value: [[0.01514343 0.00457296 0.01187909]]
# Regression Coefficients: [-0.74450151  1.27051692 -0.94146758]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 1 Foundational Institutions, 6 Economic Impact, 2.01 I-Human Capital
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.958614218713364, p-value: [[0.01050632 0.00456707 0.02915286]]
# Regression Coefficients: [-1.11820218  1.36618243 -0.41334874]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 1 Foundational Institutions, 6 Economic Impact, 3.03 E-Infrastructure
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9728497434005442, p-value: [[0.0020533  0.00148241 0.02537926]]
# Regression Coefficients: [ 1.96325696 -2.10961273  0.4269756 ]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2
Human Capital
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9089681449901114, p-value: [[0.00797971 0.00330067 0.00220236]]
# Regression Coefficients: [ 2.54798443 -4.00165907  0.95947371]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.02 I-Funding, 6 Economic Impact, 3.05 E-Culture & Incentives
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9994612029747381, p-value: [[3.06229342e-06 3.38509345e-06 1.93703635e-05]]
# Regression Coefficients: [ 1.34983765 -1.24513637 -0.38345747]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.02 I-Funding, 6 Economic Impact, GNI per capita
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.929163862865595, p-value: [[0.00112584 0.00078153 0.0028616 ]]
# Regression Coefficients: [ 3.97144797 -5.90888965  1.16063714]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.02 I-Funding, GNI per capita, 1 Foundational Institutions
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.949654152318117, p-value: [[0.04269165 0.01233738 0.00488489]]
# Regression Coefficients: [ 0.70099315 -1.26660863  0.52942099]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.02 I-Funding, GNI per capita, 2.01 I-Human Capital
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9997759156656787, p-value: [[2.58531327e-06 4.08724629e-07 1.05138209e-06]]
# Regression Coefficients: [-1.20252198  2.67789637 -0.69632219]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.02 I-Funding, GNI per capita, 2.04 I-Demand
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9636272740563524, p-value: [[0.00396816 0.00081899 0.00348651]]
# Regression Coefficients: [-0.73750961  1.84152054 -0.57107026]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.02 I-Funding, GNI per capita, 3.01 E-Human Capital
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9311999024403903, p-value: [[0.04939916 0.01338214 0.00516005]]
# Regression Coefficients: [ 0.80073241 -1.60317071  0.61209005]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.02 I-Funding, SEDA Score, 3.01 E-Human Capital
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9882599089950294, p-value: [[0.02796744 0.03364094 0.00063674]]
# Regression Coefficients: [-0.26527739 -0.27280196  0.45764899]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.04 I-Demand, 1 Foundational Institutions, 2.05 I-Culture & Incentives
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9046938072659375, p-value: [[0.00029213 0.00317127 0.04385936]]
# Regression Coefficients: [ 1.71247944 -0.56603743 -0.19052864]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.04 I-Demand, 2.03 I-Infrastructure, 3.03 E-Infrastructure
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9675813383025397, p-value: [[0.02802713 0.00159561 0.00155235]]
# Regression Coefficients: [ 0.54427847  2.50107319 -3.03211107]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.04 I-Demand, 2.03 I-Infrastructure, SEDA Score
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9510653848085855, p-value: [[0.01004919 0.00472053 0.0046661 ]]
# Regression Coefficients: [ 0.74298489  2.86324053 -3.15351839]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.04 I-Demand, 3.01 E-Human Capital, 2.05 I-Culture & Incentives
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9688788053879852, p-value: [[4.74326307e-05 9.99532470e-04 1.65653731e-03]]
# Regression Coefficients: [-1.81651102  0.5606495  -0.33459714]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.04 I-Demand, 3.02 E-Funding, 2.01 I-Human Capital
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9980879480434565, p-value: [[3.28134557e-04 3.37337755e-05 5.45265707e-05]]
# Regression Coefficients: [-0.49632872  1.93298582 -1.34292388]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.04 I-Demand, 3.02 E-Funding, 3.05 E-Culture & Incentives
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9621617790269315, p-value: [[0.00365029 0.00515457 0.00179266]]
# Regression Coefficients: [-2.66754205  1.25663095  2.05256372]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.04 I-Demand, 3.02 E-Funding, GNI per capita
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9809438150314044, p-value: [[0.00877622 0.00136199 0.00100508]]
# Regression Coefficients: [-0.43487439  1.78344914 -1.20155658]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.04 I-Demand, 3.03 E-Infrastructure, 1 Foundational Institutions
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9906637886125527, p-value: [[0.00292144 0.00025905 0.00042018]]
# Regression Coefficients: [ 0.47637389 -1.20684379  1.06433746]
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.04 I-Demand, 3.03 E-Infrastructure, 3.01 E-Human Capital
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.957566017236787, p-value: [[0.00934052 0.00497515 0.00241753]]
# Regression Coefficients: [ 0.61687534 -0.99381953  0.73038514]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.04 I-Demand, 3.04 E-Demand, 2.02 I-Funding
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9080516294106209, p-value: [[0.00869185 0.01743603 0.02257204]]
# Regression Coefficients: [ 0.93276161 -0.77985661 -0.48289776]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.04 I-Demand, 3.04 E-Demand, 3.05 E-Culture & Incentives
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9071298151927439, p-value: [[0.01300978 0.01527493 0.00812086]]
# Regression Coefficients: [-2.19644378  0.98871795  1.84678997]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.04 I-Demand, 3.04 E-Demand, 6 Economic Impact
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.953459037633099, p-value: [[0.00048928 0.00292676 0.00048934]]
# Regression Coefficients: [-2.85280234  1.26482657  3.12440426]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.04 I-Demand, GNI per capita, 2.01 I-Human Capital
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9844852554420722, p-value: [[0.00049719 0.00050988 0.00706824]]
# Regression Coefficients: [-1.01120586  2.22760346 -0.56122452]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.04 I-Demand, GNI per capita, 2.02 I-Funding
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9961267624214292, p-value: [[7.36671646e-05 2.01949013e-05 1.44608528e-04]]
# Regression Coefficients: [-0.92428371  2.07642304 -0.54624921]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.05 I-Culture & Incentives, 1 Foundational Institutions, 3.05 E-Culture & Incentives
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9832463911044024, p-value: [[5.69220372e-05 5.57962023e-04 2.09646036e-03]]
# Regression Coefficients: [ 1.33536979 -0.44385382 -0.24475422]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.05 I-Culture & Incentives, 2.01 I-Human Capital, GNI per capita
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9200654844279739, p-value: [[0.04841558 0.04770113 0.00620137]]
# Regression Coefficients: [ 0.24412252 -0.22352027 -0.36052161]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.05 I-Culture & Incentives, 2.04 I-Demand, 2.02 I-Funding
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9846881934345378, p-value: [[0.00248435 0.00776475 0.00066137]]
# Regression Coefficients: [ 0.39511109 -0.22570224 -0.34561211]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.05 I-Culture & Incentives, 2.04 I-Demand, 3.05 E-Culture & Incentives
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9861146618943215, p-value: [[0.00122182 0.03133961 0.0015725 ]]
# Regression Coefficients: [ 0.54336206 -0.12598022  0.27688373]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.05 I-Culture & Incentives, 2.04 I-Demand, 3.05 E-Culture & Incentives
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9012299208071112, p-value: [[0.00247585 0.01981836 0.03385435]]
# Regression Coefficients: [ 1.21052425 -0.42448283 -0.26309414]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.05 I-Culture & Incentives, 2.04 I-Demand, GNI per capita
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9558392090790196, p-value: [[0.02699469 0.03718459 0.00230162]]
# Regression Coefficients: [ 0.23829637 -0.19492777 -0.35939977]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.05 I-Culture & Incentives, 3.01 E-Human Capital, 2.04 I-Demand
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9959313135849472, p-value: [[4.44511781e-06 7.96033945e-05 6.65604924e-05]]
# Regression Coefficients: [-1.44706661  0.47391678 -0.35635728]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.05 I-Culture & Incentives, 3.01 E-Human Capital, 3.05 E-Culture & Incentives
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9020942148091436, p-value: [[0.00188799 0.02711161 0.02770953]]
# Regression Coefficients: [ 0.89193403 -0.27894803  0.19902632]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.05 I-Culture & Incentives, 3.02 E-Funding, 2.02 I-Funding
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9354213687667794, p-value: [[0.01594762 0.02046708 0.00417936]]
# Regression Coefficients: [ 0.43197516 -0.35267906 -0.37796972]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.05 I-Culture & Incentives, 3.03 E-Infrastructure, 2.04 I-Demand
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9298628422936298, p-value: [[0.00030318 0.00157912 0.01972538]]
# Regression Coefficients: [-1.50385177  0.6143315   0.23087156]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 2.05 I-Culture & Incentives, 3.04 E-Demand, 2.02 I-Funding
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.

#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.04 E-Demand, 3.02 E-Funding, 2.04 I-Demand
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9909055412003233, p-value: [[0.00579439 0.0004519  0.02709199]]
# Regression Coefficients: [-0.75397578  1.32018174 -0.32392312]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.04 E-Demand, 3.03 E-Infrastructure, 3.05 E-Culture & Incentives
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9621823521506284, p-value: [[0.00076828 0.00477891 0.00105262]]
# Regression Coefficients: [-1.2629296  -0.59483648  1.06933702]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.04 E-Demand, GNI per capita, 2.02 I-Funding
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9610334056794135, p-value: [[0.00669454 0.00142695 0.00629229]]
# Regression Coefficients: [-0.5333983   1.32624529 -0.43266774]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.04 E-Demand, GNI per capita, 2.04 I-Demand
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9829212687241219, p-value: [[0.00126854 0.0007631  0.02198074]]
# Regression Coefficients: [-0.64890861  1.36608947 -0.26622082]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.04 E-Demand, SEDA Score, 1 Foundational Institutions
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.997658491823074, p-value: [[1.55473883e-03 7.46898607e-05 4.99550123e-05]]
# Regression Coefficients: [-0.17006412 -0.75759448  0.82011135]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.05 E-Culture & Incentives, 1 Foundational Institutions, 2.05 I-Culture & Incentives
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9892453504881937, p-value: [[2.07320413e-05 1.69668875e-04 2.30889721e-03]]
# Regression Coefficients: [ 1.49893087 -0.53023289 -0.18974043]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.05 E-Culture & Incentives, 2.01 I-Human Capital, 3.04 E-Demand
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9571716911741054, p-value: [[0.00035465 0.0004076  0.00013792]]
# Regression Coefficients: [-1.91187685  1.72341471  1.95521973]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.05 E-Culture & Incentives, 2.02 I-Funding, 1 Foundational Institutions
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9588123794112341, p-value: [[0.02203029 0.0050575  0.01262778]]
# Regression Coefficients: [ 0.48965652 -0.81357476  0.31262425]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.05 E-Culture & Incentives, 3.02 E-Funding, 2.04 I-Demand
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9602831005915525, p-value: [[0.00646127 0.01263083 0.00232437]]
# Regression Coefficients: [-2.24116024  0.93776558  1.92460597]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.05 E-Culture & Incentives, 3.04 E-Demand, 2.04 I-Demand
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9681805421823473, p-value: [[0.00335017 0.00490161 0.00162686]]
# Regression Coefficients: [-2.07079326  0.86625579  1.88371651]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.05 E-Culture & Incentives, 3.04 E-Demand, 6 Economic Impact
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9173664093816123, p-value: [[0.00559165 0.01254086 0.00243387]]
# Regression Coefficients: [-1.7090138   0.78854145  1.72681705]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.05 E-Culture & Incentives, 6 Economic Impact, 2.02 I-Funding
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9961307531457024, p-value: [[5.76690390e-05 4.62596234e-05 1.20022879e-03]]
# Regression Coefficients: [ 1.35838285 -1.39458954 -0.25773141]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.05 E-Culture & Incentives, GNI per capita, 1 Foundational Institutions
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9634791810089639, p-value: [[0.01418208 0.00459103 0.00762309]]
# Regression Coefficients: [ 0.4816494  -0.79880615  0.36776267]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.05 E-Culture & Incentives, SEDA Score, 2.05 I-Culture & Incentives
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9285914402145532, p-value: [[0.00224368 0.02590544 0.00974941]]
# Regression Coefficients: [-0.63198238  0.19586603 -0.26124751]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 3.05 E-Culture & Incentives, SEDA Score, 3.04 E-Demand
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.925065341173679, p-value: [[0.00485915 0.00187231 0.0142859 ]]
# Regression Coefficients: [ 0.61659204  1.09608274 -0.5166848 ]
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 6 Economic Impact, 3.02 E-Funding, 3.03 E-Infrastructure
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.965563427295837, p-value: [[0.00103212 0.00600996 0.01891711]]
# Regression Coefficients: [ 2.21176311 -0.98566912 -0.82793408]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 6 Economic Impact, 3.02 E-Funding, 3.04 E-Demand
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9944657260053891, p-value: [[1.12950492e-04 1.57301152e-02 2.42265755e-05]]
# Regression Coefficients: [ 1.50838227  0.23377157 -2.2234571 ]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 6 Economic Impact, 3.04 E-Demand, 2.04 I-Demand
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.990139477633034, p-value: [[4.77372461e-05 4.09691036e-04 4.34025717e-05]]
# Regression Coefficients: [-2.8623128   1.13337739  3.23619631]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: 6 Economic Impact, GNI per capita, 2.03 I-Infrastructure
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9714170225173924, p-value: [[0.00022316 0.00023248 0.00036082]]
# Regression Coefficients: [ 12.581223   -20.41225587   6.50997148]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: GNI per capita, 2.01 I-Human Capital, 3.05 E-Culture & Incentives
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9180556196467055, p-value: [[0.0032926  0.00465837 0.02088704]]
# Regression Coefficients: [ 1.18671596 -1.26369077 -0.39588564]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: GNI per capita, 2.03 I-Infrastructure, 2.02 I-Funding
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9901264305532996, p-value: [[5.98692301e-05 3.84833865e-05 9.48166131e-05]]
# Regression Coefficients: [-4.09058231  6.01133722 -1.29170908]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: GNI per capita, 2.03 I-Infrastructure, 3.01 E-Human Capital
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9775515890234784, p-value: [[0.00822164 0.0221744  0.03137875]]
# Regression Coefficients: [-1.1581875   1.10227655  0.29721776]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: GNI per capita, 3.02 E-Funding, 2.01 I-Human Capital
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.997038663518188, p-value: [[1.00104194e-03 9.36713731e-05 8.34402273e-05]]
# Regression Coefficients: [-0.38346806  2.02960011 -1.42738118]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: GNI per capita, 3.02 E-Funding, 2.04 I-Demand
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9987578667532537, p-value: [[5.75356865e-04 2.96817544e-05 1.37801163e-05]]
# Regression Coefficients: [-0.28259985  1.64336302 -1.29038942]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: GNI per capita, 6 Economic Impact, 2.02 I-Funding
# Predicted: 4 Comparative Advantage
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.998028961511024, p-value: [[6.30586615e-06 4.02693040e-06 1.24174494e-05]]
# Regression Coefficients: [-3.75830207  5.74022594 -1.20379098]
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Predictor metrics: GNI per capita, 6 Economic Impact, 3.05 E-Culture & Incentives
# Predicted: 5 Social Impact
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Regression Score: 0.9260326959679855, p-value: [[0.0031689  0.00374498 0.03006569]]
# Regression Coefficients: [ 1.24593149 -1.39214893 -0.35003811]

# %%
'''
3D linear model for predicting impact and comparative advantage from iEcosystem metrics
'''

for key1 in ieco_key_list:                         # for each pair (a,b) of distinct ieco metrics
    for key2 in ieco_key_list:
        if key1 != key2:
            for predict in ieco_key_predictors:    #or each predictor from Impact and C. Advantage
                
                #numpy array for predicted vals: 2 rows, 6 columns
                X=np.concatenate([df_means[key1].to_numpy(),df_means[key2].to_numpy()],axis=0)
                X=X.reshape(6,2)
                
                #make a numpy array for predictor
                y=df_means[predict].to_numpy()
                
                #make a Linear regression and obtains p-value using previously defined function
                reg=LinearRegression().fit(X,y)
                p=lin_reg_p_val(reg,X,y)
                
                #if both p-values are small enough and the linear regression score is greater than 0.8
                if p[0][0]<.05 and p[0][1]<.05 and reg.score(X,y)>.8:
                    print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -')
                    print('Predictor metrics: '+key1+', '+key2)
                    print('Predicted: '+predict)
                    print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -')
                    print('Regression Score: ' + str(reg.score(X,y)) + ', p-value: ' + str(p) )
                    print('Regression Coefficients: ' + str(reg.coef_) )
                    print('Intercept: ' + str(reg.intercept_))
                    plot_linear_model(reg,X,y,key1,key2,predict)
                    print('')
                    print('')
                    print('')

# %%
'''
3D linear models for predicting impact and comparative advantage using graph metrics
'''
# list of all global metrics
grf_key_list=list(grf_df.keys())

# our two predictors
ieco_key_predictors=['4 Comparative Advantage','5 Impact']    

for key1 in grf_key_list:
    for key2 in grf_key_list:                                 # for each pair (a,b) of distinct global metrics
        if key1 != key2:                                      
            for predict in ieco_key_predictors:               # and each predictor
                
                # we make a numpy array with the predicted values and reshape it into 2 rows, 6 columns
                #X = np.concatenate([ieco_grf_df[key1].to_numpy(),ieco_grf_df[key2].to_numpy()],axis=0)
                X = np.concatenate([ieco_grf_df[key1].to_numpy(),ieco_grf_df[key2].to_numpy()],axis=0)
                X = X.reshape(6,2)
                
                # make a numpy array for our predictor
                y=ieco_grf_df[predict].to_numpy()
                
                #make linear regression with X,y data and obtain p-value
                reg=LinearRegression().fit(X,y)
                p=lin_reg_p_val(reg,X,y)
                
                #if p-value is small enough and the regression score is greater than 0.8:
                if p[0][0]<.05 and p[0][1]<.05 and reg.score(X,y)>.8:
                    print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -')
                    print('Predictor metrics: '+key1+', '+key2)
                    print('Predicted: '+predict)
                    print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -')
                    print('Regression Score: ' + str(reg.score(X,y)) + ', p-value: ' + str(p) )
                    print('Regression Coefficients: ' + str(reg.coef_) )
                    print('Intercept: ' + str(reg.intercept_))
                    plot_linear_model(reg,X,y,key1,key2,predict)
                    print('')
                    print('')
                    print('')

# %%
'''
3D linear models for predicting iEcosystem metrics using graph metrics
'''
# list of all global metrics
grf_key_list=list(grf_df.keys())                     

#iEco metrics predictors/to be predicted
ieco_key_list=list(df_means.keys())                           

for key1 in grf_key_list:
    for key2 in grf_key_list:                                 # for each pair (a,b) of distinct global metrics
        if key1 != key2:                                      
            for predict in ieco_key_list:               # and each predictor
                
                # we make a numpy array with the predicted values and reshape it into 2 rows, 6 columns
                X = np.concatenate([ieco_grf_df[key1].to_numpy(),ieco_grf_df[key2].to_numpy()],axis=0)
                X = X.reshape(6,2)
                
                # make a numpy array for our predictor
                y=ieco_grf_df[predict].to_numpy()
                
                #make linear regression with X,y data and obtain p-value
                reg=LinearRegression().fit(X,y)
                p=lin_reg_p_val(reg,X,y)
                
                #if p-value is small enough and the regression score is greater than 0.8:
                if p[0][0]<.05 and p[0][1]<.05 and reg.score(X,y)>.8:
                    print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -')
                    print('Predictor metrics: '+key1+', '+key2)
                    print('Predicted: '+predict)
                    print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -')
                    print('Regression Score: ' + str(reg.score(X,y)) + ', p-value: ' + str(p) )
                    print('Regression Coefficients: ' + str(reg.coef_) )
                    print('Intercept: ' + str(reg.intercept_))
                    plot_linear_model(reg,X,y,key1,key2,predict)
                    print('')
                    print('')
                    print('')

# %%
ranking_df
